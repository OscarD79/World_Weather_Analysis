# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# Import citipy from citipy library
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# print(weather_api_key)
# Import datetime to recast api date as a datetime format

# Import the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list of Cities
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 792

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # print(requests.get(city_url).json())
 
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | beruwala
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | taoudenni
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | vila
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | te anau
# Processing Record 14 of Set 1 | moree
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | ulcinj
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | kikwit
# Processing Record 21 of Set 1 | henties bay
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | saint anthony
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | saint-georges
# Processing Record 27 of Set 1 | kattivakkam
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | kidal
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | jutai
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | el alto
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | wanaka
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | ouro preto do oeste
# Processing Record 38 of Set 1 | srandakan
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | hun
# Processing Record 43 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | bayanday
# Processing Record 48 of Set 1 | saint-denis
# Processing Record 49 of Set 1 | gazli
# Processing Record 50 of Set 1 | poum
# Processing Record 1 of Set 2 | sinnamary
# Processing Record 2 of Set 2 | tuensang
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | inuvik
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | bud
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | muros
# Processing Record 12 of Set 2 | crotone
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | sembe
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | qasigiannguit
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | nuevo laredo
# Processing Record 21 of Set 2 | lamu
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | cloquet
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | yanji
# Processing Record 26 of Set 2 | sumbe
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | altona
# Processing Record 30 of Set 2 | narsaq
# Processing Record 31 of Set 2 | sao jose do rio preto
# Processing Record 32 of Set 2 | shu
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | codrington
# Processing Record 35 of Set 2 | pervomayskoye
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | nara
# Processing Record 38 of Set 2 | marzuq
# Processing Record 39 of Set 2 | grande prairie
# Processing Record 40 of Set 2 | yarmouth
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | aswan
# Processing Record 43 of Set 2 | vaitape
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | karratha
# Processing Record 46 of Set 2 | boa vista
# Processing Record 47 of Set 2 | mizdah
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | sillod
# Processing Record 50 of Set 2 | machinga
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | usinsk
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | vuktyl
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | maragogi
# Processing Record 10 of Set 3 | samarinda
# Processing Record 11 of Set 3 | caravelas
# Processing Record 12 of Set 3 | yar
# Processing Record 13 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 3 | sur
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | hami
# Processing Record 17 of Set 3 | hammerfest
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | kirakira
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | muisne
# Processing Record 23 of Set 3 | coihaique
# Processing Record 24 of Set 3 | mumford
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | gao
# Processing Record 27 of Set 3 | bajil
# Processing Record 28 of Set 3 | sao gabriel da cachoeira
# Processing Record 29 of Set 3 | dunedin
# Processing Record 30 of Set 3 | porto novo
# Processing Record 31 of Set 3 | kaardi
# City not found. Skipping...
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | grand gaube
# Processing Record 35 of Set 3 | college
# Processing Record 36 of Set 3 | half moon bay
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 39 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 40 of Set 3 | kieta
# Processing Record 41 of Set 3 | mansehra
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | mugur-aksy
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | ballina
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | kendari
# Processing Record 50 of Set 3 | pemba
# Processing Record 1 of Set 4 | namibe
# Processing Record 2 of Set 4 | asyut
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | santa cruz de tenerife
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 4 | aklavik
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | svetlogorsk
# Processing Record 10 of Set 4 | juneau
# Processing Record 11 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 4 | paita
# Processing Record 13 of Set 4 | koslan
# Processing Record 14 of Set 4 | sao felix do xingu
# Processing Record 15 of Set 4 | los andes
# Processing Record 16 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 4 | nouadhibou
# Processing Record 18 of Set 4 | puerto ayora
# Processing Record 19 of Set 4 | okato
# Processing Record 20 of Set 4 | minab
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | batemans bay
# Processing Record 23 of Set 4 | talara
# Processing Record 24 of Set 4 | linkoping
# Processing Record 25 of Set 4 | selenginsk
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | teahupoo
# Processing Record 29 of Set 4 | baran
# Processing Record 30 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 4 | gudibanda
# Processing Record 32 of Set 4 | muroto
# Processing Record 33 of Set 4 | huadian
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | nagato
# Processing Record 36 of Set 4 | beboto
# Processing Record 37 of Set 4 | ayan
# Processing Record 38 of Set 4 | ostrovnoy
# Processing Record 39 of Set 4 | nioro
# Processing Record 40 of Set 4 | kontagora
# Processing Record 41 of Set 4 | tallahassee
# Processing Record 42 of Set 4 | tarrafal
# Processing Record 43 of Set 4 | huarmey
# Processing Record 44 of Set 4 | hailun
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | emerald
# Processing Record 47 of Set 4 | havelock
# Processing Record 48 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 4 | komsomolskiy
# Processing Record 50 of Set 4 | constantine
# Processing Record 1 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | rjukan
# Processing Record 4 of Set 5 | pevek
# Processing Record 5 of Set 5 | haines junction
# Processing Record 6 of Set 5 | ferrol
# Processing Record 7 of Set 5 | huangchuan
# Processing Record 8 of Set 5 | williams lake
# Processing Record 9 of Set 5 | idritsa
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 5 | dorchester
# Processing Record 13 of Set 5 | auki
# Processing Record 14 of Set 5 | airai
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | mehamn
# Processing Record 17 of Set 5 | necochea
# Processing Record 18 of Set 5 | puerto escondido
# Processing Record 19 of Set 5 | birao
# Processing Record 20 of Set 5 | champerico
# Processing Record 21 of Set 5 | gusinoye ozero
# Processing Record 22 of Set 5 | sal rei
# Processing Record 23 of Set 5 | dong hoi
# Processing Record 24 of Set 5 | ambilobe
# Processing Record 25 of Set 5 | hofn
# Processing Record 26 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | arman
# Processing Record 29 of Set 5 | roma
# Processing Record 30 of Set 5 | meulaboh
# Processing Record 31 of Set 5 | port hedland
# Processing Record 32 of Set 5 | bonavista
# Processing Record 33 of Set 5 | bitung
# Processing Record 34 of Set 5 | les cayes
# Processing Record 35 of Set 5 | margate
# Processing Record 36 of Set 5 | ancud
# Processing Record 37 of Set 5 | moses lake
# Processing Record 38 of Set 5 | sarahan
# Processing Record 39 of Set 5 | les herbiers
# Processing Record 40 of Set 5 | mineros
# Processing Record 41 of Set 5 | vagay
# Processing Record 42 of Set 5 | kem
# Processing Record 43 of Set 5 | tchollire
# Processing Record 44 of Set 5 | gangtok
# Processing Record 45 of Set 5 | kota belud
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | andenes
# Processing Record 48 of Set 5 | constitucion
# Processing Record 49 of Set 5 | kamina
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | jalu
# Processing Record 2 of Set 6 | oranjestad
# Processing Record 3 of Set 6 | lebu
# Processing Record 4 of Set 6 | sinop
# Processing Record 5 of Set 6 | matale
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | spornoye
# Processing Record 9 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 10 of Set 6 | kalispell
# Processing Record 11 of Set 6 | rio grande
# Processing Record 12 of Set 6 | glendive
# Processing Record 13 of Set 6 | khatanga
# Processing Record 14 of Set 6 | chanthaburi
# Processing Record 15 of Set 6 | ayagoz
# Processing Record 16 of Set 6 | bingol
# Processing Record 17 of Set 6 | vung tau
# Processing Record 18 of Set 6 | upernavik
# Processing Record 19 of Set 6 | niimi
# Processing Record 20 of Set 6 | chifeng
# Processing Record 21 of Set 6 | tezu
# Processing Record 22 of Set 6 | alekseyevka
# Processing Record 23 of Set 6 | acarau
# Processing Record 24 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 6 | aurillac
# Processing Record 26 of Set 6 | boyolangu
# Processing Record 27 of Set 6 | nelson bay
# Processing Record 28 of Set 6 | biala podlaska
# Processing Record 29 of Set 6 | whitley bay
# Processing Record 30 of Set 6 | la tuque
# Processing Record 31 of Set 6 | medicine hat
# Processing Record 32 of Set 6 | lompoc
# Processing Record 33 of Set 6 | tautira
# Processing Record 34 of Set 6 | gigmoto
# Processing Record 35 of Set 6 | ponta do sol
# Processing Record 36 of Set 6 | thinadhoo
# Processing Record 37 of Set 6 | naze
# Processing Record 38 of Set 6 | chute-aux-outardes
# Processing Record 39 of Set 6 | fort-shevchenko
# Processing Record 40 of Set 6 | waitati
# Processing Record 41 of Set 6 | mount pleasant
# Processing Record 42 of Set 6 | nishihara
# Processing Record 43 of Set 6 | calvinia
# Processing Record 44 of Set 6 | alexandria
# Processing Record 45 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 46 of Set 6 | capelinha
# Processing Record 47 of Set 6 | eureka
# Processing Record 48 of Set 6 | katsuura
# Processing Record 49 of Set 6 | mikhaylovskoye
# Processing Record 50 of Set 6 | novikovo
# Processing Record 1 of Set 7 | hambantota
# Processing Record 2 of Set 7 | benguela
# Processing Record 3 of Set 7 | tuatapere
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 7 | aitape
# Processing Record 7 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | padilla
# Processing Record 10 of Set 7 | bathsheba
# Processing Record 11 of Set 7 | abu samrah
# Processing Record 12 of Set 7 | jabinyanah
# Processing Record 13 of Set 7 | sarakhs
# Processing Record 14 of Set 7 | arlit
# Processing Record 15 of Set 7 | salalah
# Processing Record 16 of Set 7 | kholmogory
# Processing Record 17 of Set 7 | piacabucu
# Processing Record 18 of Set 7 | mormugao
# Processing Record 19 of Set 7 | tommot
# Processing Record 20 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 7 | ust-nera
# Processing Record 22 of Set 7 | manono
# Processing Record 23 of Set 7 | opuwo
# Processing Record 24 of Set 7 | georgetown
# Processing Record 25 of Set 7 | binga
# Processing Record 26 of Set 7 | naranjal
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | robertsport
# Processing Record 29 of Set 7 | mana
# Processing Record 30 of Set 7 | cherdyn
# Processing Record 31 of Set 7 | halifax
# Processing Record 32 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 7 | mombetsu
# Processing Record 34 of Set 7 | buchanan
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | riyadh
# Processing Record 37 of Set 7 | villarrica
# Processing Record 38 of Set 7 | hay river
# Processing Record 39 of Set 7 | morondava
# Processing Record 40 of Set 7 | omboue
# Processing Record 41 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 7 | orlik
# Processing Record 43 of Set 7 | luanda
# Processing Record 44 of Set 7 | ahuimanu
# Processing Record 45 of Set 7 | huangnihe
# Processing Record 46 of Set 7 | susurluk
# Processing Record 47 of Set 7 | flinders
# Processing Record 48 of Set 7 | camacari
# Processing Record 49 of Set 7 | chimore
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | sampit
# Processing Record 2 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 8 | sangar
# Processing Record 4 of Set 8 | fort nelson
# Processing Record 5 of Set 8 | waddan
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | taywarah
# Processing Record 8 of Set 8 | vilshofen
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | hrymayliv
# Processing Record 11 of Set 8 | paamiut
# Processing Record 12 of Set 8 | coro
# Processing Record 13 of Set 8 | buala
# Processing Record 14 of Set 8 | tuktoyaktuk
# Processing Record 15 of Set 8 | bardiyah
# Processing Record 16 of Set 8 | nakanojo
# Processing Record 17 of Set 8 | thai binh
# Processing Record 18 of Set 8 | zhezkazgan
# Processing Record 19 of Set 8 | azangaro
# Processing Record 20 of Set 8 | norman wells
# Processing Record 21 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 8 | weston
# Processing Record 23 of Set 8 | san cristobal
# Processing Record 24 of Set 8 | coahuayana
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | kisaran
# Processing Record 27 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 8 | kumta
# Processing Record 29 of Set 8 | dubna
# Processing Record 30 of Set 8 | cherskiy
# Processing Record 31 of Set 8 | savantvadi
# Processing Record 32 of Set 8 | saint-augustin
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | chardara
# Processing Record 35 of Set 8 | naica
# Processing Record 36 of Set 8 | kutum
# Processing Record 37 of Set 8 | kimbe
# Processing Record 38 of Set 8 | naryan-mar
# Processing Record 39 of Set 8 | bakchar
# Processing Record 40 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 41 of Set 8 | fraga
# Processing Record 42 of Set 8 | salta
# Processing Record 43 of Set 8 | tura
# Processing Record 44 of Set 8 | ghorawal
# Processing Record 45 of Set 8 | provideniya
# Processing Record 46 of Set 8 | gerash
# Processing Record 47 of Set 8 | kisangani
# Processing Record 48 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 8 | bhainsa
# Processing Record 50 of Set 8 | lyubytino
# Processing Record 1 of Set 9 | ratnagiri
# Processing Record 2 of Set 9 | niksar
# Processing Record 3 of Set 9 | ledyard
# Processing Record 4 of Set 9 | husavik
# Processing Record 5 of Set 9 | osypenko
# Processing Record 6 of Set 9 | prachuap khiri khan
# Processing Record 7 of Set 9 | harper
# Processing Record 8 of Set 9 | ardesen
# Processing Record 9 of Set 9 | zhob
# Processing Record 10 of Set 9 | acton vale
# Processing Record 11 of Set 9 | gorele
# Processing Record 12 of Set 9 | moron
# Processing Record 13 of Set 9 | waitara
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | grindavik
# Processing Record 17 of Set 9 | comodoro rivadavia
# Processing Record 18 of Set 9 | imbituba
# Processing Record 19 of Set 9 | ngunguru
# Processing Record 20 of Set 9 | coquimbo
# Processing Record 21 of Set 9 | santo angelo
# Processing Record 22 of Set 9 | palmer
# Processing Record 23 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 9 | boromo
# Processing Record 26 of Set 9 | yalta
# Processing Record 27 of Set 9 | ananas
# Processing Record 28 of Set 9 | fortaleza
# Processing Record 29 of Set 9 | tukrah
# Processing Record 30 of Set 9 | kanpur
# Processing Record 31 of Set 9 | canico
# Processing Record 32 of Set 9 | vila velha
# Processing Record 33 of Set 9 | vanavara
# Processing Record 34 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 9 | ketchikan
# Processing Record 36 of Set 9 | verkhoyansk
# Processing Record 37 of Set 9 | wakkanai
# Processing Record 38 of Set 9 | evensk
# Processing Record 39 of Set 9 | polunochnoye
# Processing Record 40 of Set 9 | bowen
# Processing Record 41 of Set 9 | tabou
# Processing Record 42 of Set 9 | dingle
# Processing Record 43 of Set 9 | tripoli
# Processing Record 44 of Set 9 | udgir
# Processing Record 45 of Set 9 | victoria
# Processing Record 46 of Set 9 | nucsoara
# Processing Record 47 of Set 9 | palencia
# Processing Record 48 of Set 9 | manjeshwar
# Processing Record 49 of Set 9 | marfino
# Processing Record 50 of Set 9 | beidao
# Processing Record 1 of Set 10 | grand-lahou
# Processing Record 2 of Set 10 | matamoros
# Processing Record 3 of Set 10 | meadow lake
# Processing Record 4 of Set 10 | mortka
# Processing Record 5 of Set 10 | bandarbeyla
# Processing Record 6 of Set 10 | beyneu
# Processing Record 7 of Set 10 | andros town
# Processing Record 8 of Set 10 | jacareacanga
# Processing Record 9 of Set 10 | talcahuano
# Processing Record 10 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 10 | oussouye
# Processing Record 12 of Set 10 | ruteng
# Processing Record 13 of Set 10 | bulawayo
# Processing Record 14 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 10 | batagay-alyta
# Processing Record 16 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 10 | byron bay
# Processing Record 18 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 10 | beringovskiy
# Processing Record 20 of Set 10 | beirut
# Processing Record 21 of Set 10 | karasburg
# Processing Record 22 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 10 | bolgar
# Processing Record 24 of Set 10 | silleda
# Processing Record 25 of Set 10 | pisco
# Processing Record 26 of Set 10 | daru
# Processing Record 27 of Set 10 | ushtobe
# Processing Record 28 of Set 10 | fairbanks
# Processing Record 29 of Set 10 | cua
# Processing Record 30 of Set 10 | amahai
# Processing Record 31 of Set 10 | chiredzi
# Processing Record 32 of Set 10 | shimoda
# Processing Record 33 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 10 | puri
# Processing Record 35 of Set 10 | poya
# Processing Record 36 of Set 10 | middelburg
# Processing Record 37 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 10 | zhangye
# Processing Record 39 of Set 10 | acapulco
# Processing Record 40 of Set 10 | ribeira grande
# Processing Record 41 of Set 10 | leningradskiy
# Processing Record 42 of Set 10 | lata
# Processing Record 43 of Set 10 | kampot
# Processing Record 44 of Set 10 | zhigalovo
# Processing Record 45 of Set 10 | itigi
# Processing Record 46 of Set 10 | tagusao
# Processing Record 47 of Set 10 | dzhebariki-khaya
# Processing Record 48 of Set 10 | matsanga
# City not found. Skipping...
# Processing Record 49 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 10 | talcher
# Processing Record 1 of Set 11 | mirnyy
# Processing Record 2 of Set 11 | ugoofaaru
# Processing Record 3 of Set 11 | pitea
# Processing Record 4 of Set 11 | vila franca do campo
# Processing Record 5 of Set 11 | clyde river
# Processing Record 6 of Set 11 | belmonte
# Processing Record 7 of Set 11 | asha
# Processing Record 8 of Set 11 | ilovlya
# Processing Record 9 of Set 11 | placido de castro
# Processing Record 10 of Set 11 | luganville
# Processing Record 11 of Set 11 | utete
# Processing Record 12 of Set 11 | igarka
# Processing Record 13 of Set 11 | namatanai
# Processing Record 14 of Set 11 | chateaubelair
# Processing Record 15 of Set 11 | yaypan
# Processing Record 16 of Set 11 | teguise
# Processing Record 17 of Set 11 | kungurtug
# Processing Record 18 of Set 11 | santa cruz
# Processing Record 19 of Set 11 | porbandar
# Processing Record 20 of Set 11 | tigpalay
# Processing Record 21 of Set 11 | altay
# Processing Record 22 of Set 11 | bereda
# Processing Record 23 of Set 11 | road town
# Processing Record 24 of Set 11 | douglas
# Processing Record 25 of Set 11 | sola
# Processing Record 26 of Set 11 | sobolevo
# Processing Record 27 of Set 11 | ullal
# Processing Record 28 of Set 11 | vangaindrano
# Processing Record 29 of Set 11 | townsville
# Processing Record 30 of Set 11 | srednekolymsk
# Processing Record 31 of Set 11 | maxixe
# Processing Record 32 of Set 11 | lakshmipur
# Processing Record 33 of Set 11 | myitkyina
# Processing Record 34 of Set 11 | gamba
# Processing Record 35 of Set 11 | visby
# Processing Record 36 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 11 | gayny
# Processing Record 38 of Set 11 | udachnyy
# Processing Record 39 of Set 11 | novopskov
# Processing Record 40 of Set 11 | vao
# Processing Record 41 of Set 11 | zaltan
# Processing Record 42 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 43 of Set 11 | tiradentes
# Processing Record 44 of Set 11 | tatawin
# Processing Record 45 of Set 11 | dharchula
# Processing Record 46 of Set 11 | mount isa
# Processing Record 47 of Set 11 | arvin
# Processing Record 48 of Set 11 | nedjo
# Processing Record 49 of Set 11 | bay roberts
# Processing Record 50 of Set 11 | yumen
# Processing Record 1 of Set 12 | minas
# Processing Record 2 of Set 12 | kitimat
# Processing Record 3 of Set 12 | kanigiri
# Processing Record 4 of Set 12 | tinos
# Processing Record 5 of Set 12 | alice springs
# Processing Record 6 of Set 12 | lubumbashi
# Processing Record 7 of Set 12 | prince rupert
# Processing Record 8 of Set 12 | svetlaya
# Processing Record 9 of Set 12 | catamarca
# Processing Record 10 of Set 12 | manzhouli
# Processing Record 11 of Set 12 | marsh harbour
# Processing Record 12 of Set 12 | beloha
# Processing Record 13 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | gumia
# Processing Record 16 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 12 | oktyabrskiy
# Processing Record 19 of Set 12 | isiolo
# Processing Record 20 of Set 12 | rocky mountain house
# Processing Record 21 of Set 12 | quang ngai
# Processing Record 22 of Set 12 | stromness
# Processing Record 23 of Set 12 | rio gallegos
# Processing Record 24 of Set 12 | lisakovsk
# Processing Record 25 of Set 12 | san antonio
# Processing Record 26 of Set 12 | westport
# Processing Record 27 of Set 12 | wamba
# Processing Record 28 of Set 12 | mnogovershinnyy
# Processing Record 29 of Set 12 | ayr
# Processing Record 30 of Set 12 | port-cartier
# Processing Record 31 of Set 12 | karaikkudi
# Processing Record 32 of Set 12 | los llanos de aridane
# Processing Record 33 of Set 12 | manta
# Processing Record 34 of Set 12 | tinjah
# City not found. Skipping...
# Processing Record 35 of Set 12 | yeniseysk
# Processing Record 36 of Set 12 | cururupu
# Processing Record 37 of Set 12 | matagami
# Processing Record 38 of Set 12 | banjar
# Processing Record 39 of Set 12 | goya
# Processing Record 40 of Set 12 | north bend
# Processing Record 41 of Set 12 | la plaine
# Processing Record 42 of Set 12 | antalaha
# Processing Record 43 of Set 12 | karasjok
# Processing Record 44 of Set 12 | lagoa
# Processing Record 45 of Set 12 | kyaikto
# Processing Record 46 of Set 12 | tazovskiy
# Processing Record 47 of Set 12 | samarai
# Processing Record 48 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 12 | durban
# Processing Record 50 of Set 12 | lapua
# Processing Record 1 of Set 13 | nangomba
# Processing Record 2 of Set 13 | black river
# Processing Record 3 of Set 13 | padang
# Processing Record 4 of Set 13 | general roca
# Processing Record 5 of Set 13 | tessalit
# Processing Record 6 of Set 13 | zyryanka
# Processing Record 7 of Set 13 | alofi
# Processing Record 8 of Set 13 | cooma
# Processing Record 9 of Set 13 | rassvet
# Processing Record 10 of Set 13 | motala
# Processing Record 11 of Set 13 | empangeni
# Processing Record 12 of Set 13 | jomalig
# City not found. Skipping...
# Processing Record 13 of Set 13 | nurota
# Processing Record 14 of Set 13 | susangerd
# Processing Record 15 of Set 13 | pitimbu
# Processing Record 16 of Set 13 | contamana
# Processing Record 17 of Set 13 | jiblah
# Processing Record 18 of Set 13 | saint-pierre
# Processing Record 19 of Set 13 | anadyr
# Processing Record 20 of Set 13 | bubaque
# Processing Record 21 of Set 13 | makakilo city
# Processing Record 22 of Set 13 | neuquen
# Processing Record 23 of Set 13 | ermelo
# Processing Record 24 of Set 13 | simoes
# Processing Record 25 of Set 13 | muhos
# Processing Record 26 of Set 13 | chongwe
# Processing Record 27 of Set 13 | pochutla
# Processing Record 28 of Set 13 | collie
# Processing Record 29 of Set 13 | bontang
# Processing Record 30 of Set 13 | kerema
# Processing Record 31 of Set 13 | biloxi
# Processing Record 32 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 13 | togur
# Processing Record 34 of Set 13 | faanui
# Processing Record 35 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 13 | moissala
# Processing Record 37 of Set 13 | jumla
# Processing Record 38 of Set 13 | mount gambier
# Processing Record 39 of Set 13 | carahue
# Processing Record 40 of Set 13 | urumqi
# Processing Record 41 of Set 13 | xinan
# Processing Record 42 of Set 13 | haicheng
# Processing Record 43 of Set 13 | russell
# Processing Record 44 of Set 13 | hamada
# Processing Record 45 of Set 13 | inhambane
# Processing Record 46 of Set 13 | puerto el triunfo
# Processing Record 47 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 13 | missungwi
# Processing Record 49 of Set 13 | ler
# Processing Record 50 of Set 13 | matara
# Processing Record 1 of Set 14 | pierre
# Processing Record 2 of Set 14 | vostok
# Processing Record 3 of Set 14 | port augusta
# Processing Record 4 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 14 | chicama
# Processing Record 6 of Set 14 | gat
# Processing Record 7 of Set 14 | zaozerne
# Processing Record 8 of Set 14 | broken hill
# Processing Record 9 of Set 14 | muslyumovo
# Processing Record 10 of Set 14 | tabatinga
# Processing Record 11 of Set 14 | darab
# Processing Record 12 of Set 14 | iranshahr
# Processing Record 13 of Set 14 | lavrentiya
# Processing Record 14 of Set 14 | mardin
# Processing Record 15 of Set 14 | kuliyapitiya
# Processing Record 16 of Set 14 | ewa beach
# Processing Record 17 of Set 14 | barcelona
# Processing Record 18 of Set 14 | nuevitas
# Processing Record 19 of Set 14 | lagos
# Processing Record 20 of Set 14 | suntar
# Processing Record 21 of Set 14 | biak
# Processing Record 22 of Set 14 | maua
# Processing Record 23 of Set 14 | hamilton
# Processing Record 24 of Set 14 | chernyshevskiy
# Processing Record 25 of Set 14 | iskateley
# Processing Record 26 of Set 14 | avera
# Processing Record 27 of Set 14 | fare
# Processing Record 28 of Set 14 | phalaborwa
# Processing Record 29 of Set 14 | antofagasta
# Processing Record 30 of Set 14 | yilan
# Processing Record 31 of Set 14 | tonantins
# Processing Record 32 of Set 14 | ipixuna
# Processing Record 33 of Set 14 | rengasdengklok
# Processing Record 34 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 14 | greensburg
# Processing Record 36 of Set 14 | zemio
# Processing Record 37 of Set 14 | merrill
# Processing Record 38 of Set 14 | provost
# Processing Record 39 of Set 14 | pangnirtung
# Processing Record 40 of Set 14 | la ronge
# Processing Record 41 of Set 14 | agadir
# Processing Record 42 of Set 14 | eenhana
# Processing Record 43 of Set 14 | purpe
# Processing Record 44 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 14 | shelburne
# Processing Record 46 of Set 14 | garowe
# Processing Record 47 of Set 14 | ulagan
# Processing Record 48 of Set 14 | kasongo-lunda
# Processing Record 49 of Set 14 | umm lajj
# Processing Record 50 of Set 14 | ocho rios
# Processing Record 1 of Set 15 | mende
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 15 | bushehr
# Processing Record 5 of Set 15 | gazanjyk
# Processing Record 6 of Set 15 | barcelos
# Processing Record 7 of Set 15 | diffa
# Processing Record 8 of Set 15 | belyy yar
# Processing Record 9 of Set 15 | gold coast
# Processing Record 10 of Set 15 | zhigansk
# Processing Record 11 of Set 15 | el wasta
# City not found. Skipping...
# Processing Record 12 of Set 15 | carauari
# Processing Record 13 of Set 15 | nacala
# Processing Record 14 of Set 15 | shirokiy
# Processing Record 15 of Set 15 | parana
# Processing Record 16 of Set 15 | evanston
# Processing Record 17 of Set 15 | nowy dwor gdanski
# Processing Record 18 of Set 15 | denpasar
# Processing Record 19 of Set 15 | gizo
# Processing Record 20 of Set 15 | kesan
# Processing Record 21 of Set 15 | san quintin
# Processing Record 22 of Set 15 | tirat karmel
# Processing Record 23 of Set 15 | dzaoudzi
# Processing Record 24 of Set 15 | visnes
# Processing Record 25 of Set 15 | baiquan
# Processing Record 26 of Set 15 | yatou
# Processing Record 27 of Set 15 | conakry
# Processing Record 28 of Set 15 | awjilah
# Processing Record 29 of Set 15 | gerede
# Processing Record 30 of Set 15 | roblin
# Processing Record 31 of Set 15 | axim
# Processing Record 32 of Set 15 | pimentel
# Processing Record 33 of Set 15 | berlevag
# Processing Record 34 of Set 15 | nador
# Processing Record 35 of Set 15 | outlook
# Processing Record 36 of Set 15 | maarianhamina
# Processing Record 37 of Set 15 | payson
# Processing Record 38 of Set 15 | umba
# Processing Record 39 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 15 | nemuro
# Processing Record 41 of Set 15 | peabiru
# Processing Record 42 of Set 15 | tunceli
# Processing Record 43 of Set 15 | kumasi
# Processing Record 44 of Set 15 | marshall
# Processing Record 45 of Set 15 | broome
# Processing Record 46 of Set 15 | mezen
# Processing Record 47 of Set 15 | hualmay
# Processing Record 48 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 15 | andrelandia
# Processing Record 50 of Set 15 | neftekamsk
# Processing Record 1 of Set 16 | garissa
# Processing Record 2 of Set 16 | bayan
# Processing Record 3 of Set 16 | izhma
# Processing Record 4 of Set 16 | sisimiut
# Processing Record 5 of Set 16 | las tunas
# Processing Record 6 of Set 16 | yarada
# Processing Record 7 of Set 16 | la asuncion
# Processing Record 8 of Set 16 | zonalnoye
# City not found. Skipping...
# Processing Record 9 of Set 16 | okha
# Processing Record 10 of Set 16 | isiro
# Processing Record 11 of Set 16 | atar
# Processing Record 12 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 16 | kyra
# Processing Record 14 of Set 16 | kolpashevo
# Processing Record 15 of Set 16 | sabzevar
# Processing Record 16 of Set 16 | praia
# Processing Record 17 of Set 16 | bosaso
# Processing Record 18 of Set 16 | pangoa
# Processing Record 19 of Set 16 | plettenberg bay
# Processing Record 20 of Set 16 | rieti
# Processing Record 21 of Set 16 | belmopan
# Processing Record 22 of Set 16 | adrar
# Processing Record 23 of Set 16 | erenhot
# Processing Record 24 of Set 16 | mahibadhoo
# Processing Record 25 of Set 16 | riohacha
# Processing Record 26 of Set 16 | souillac
# Processing Record 27 of Set 16 | cedar city
# Processing Record 28 of Set 16 | caleta de carquin
# Processing Record 29 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 16 | whitehorse
# Processing Record 31 of Set 16 | pontianak
# Processing Record 32 of Set 16 | karpathos
# Processing Record 33 of Set 16 | sotuta
# Processing Record 34 of Set 16 | uruzgan
# Processing Record 35 of Set 16 | popondetta
# Processing Record 36 of Set 16 | flin flon
# Processing Record 37 of Set 16 | wuzhou
# Processing Record 38 of Set 16 | kloulklubed
# Processing Record 39 of Set 16 | puro
# Processing Record 40 of Set 16 | shanhetun
# Processing Record 41 of Set 16 | natal
# Processing Record 42 of Set 16 | calama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Iqaluit  63.7506  -68.5145     40.73        93         100
# 1    New Norfolk -42.7826  147.0587     43.92        79         100
# 2      Cape Town -33.9258   18.4232     48.90        91          20
# 3       Beruwala   6.4788   79.9828     78.42        87         100
# 4  Mar Del Plata -38.0023  -57.5575     55.09        84           0
# 5         Hobart -42.8794  147.3294     44.26        82          75
# 6        Ushuaia -54.8000  -68.3000     46.06        53          40
# 7      Taoudenni  22.6783   -3.9836    101.14        22          86
# 8    Port Alfred -33.5906   26.8910     58.17        62          94
# 9           Vila  42.0304   -8.1588     70.68        56           0
#
#    Wind Speed Country                 Date
# 0        6.91      CA  2022-07-30 20:56:05
# 1        3.00      AU  2022-07-30 20:53:40
# 2        4.61      ZA  2022-07-30 20:56:05
# 3        8.39      LK  2022-07-30 20:56:06
# 4        7.00      AR  2022-07-30 20:56:06
# 5        8.05      AU  2022-07-30 20:56:06
# 6       12.66      AR  2022-07-30 20:51:28
# 7        6.35      ML  2022-07-30 20:56:07
# 8       15.57      ZA  2022-07-30 20:56:07
# 9        4.83      PT  2022-07-30 20:56:07

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
